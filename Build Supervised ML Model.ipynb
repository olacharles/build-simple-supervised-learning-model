# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load, Explore and Clean Data

# %%
train = pd.read_csv('train_data.csv')
test = pd.read_csv('test_data.csv')

# %%
train_copy = train.copy()
test_copy = test.copy()

# %%
train.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0   1                  26                 7                3        1
# 1   2                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   4                   7                 7                5        1
# 4   5                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#   Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
train.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0   1                  26                 7                3        1
# 1   2                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   4                   7                 7                5        1
# 4   5                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
# ...

# %%
test.head()
# Out:
#     ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  501                  23                 9                6        1
# 1  502                  23                 9                6        1
# 2  503                  23                 9                2        1
# 3  504                  23                 9                4        1
# 4  505                  23                 9                2        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     179                               26             9   30
# 1                     248                               25            14   47
# 2                     179                               51            18   38
# 3                     225                               26             9   28
# 4                     179                               26             9   30
#
# ...

# %%
train.shape, test.shape
# Out:
# ((500, 21), (240, 20))

# %%
train.describe().transpose()
# Out:
#                                  count     mean         std    min     25%  \
# ID                               500.0  250.500  144.481833    1.0  125.75
# Reason for absence               500.0   19.288    8.543245    0.0   13.00
# Month of absence                 500.0    6.614    3.343555    1.0    3.75
# Day of the week                  500.0    3.880    1.435870    2.0    3.00
# Seasons                          500.0    2.450    1.165425    1.0    1.00
# Transportation expense           500.0  223.640   67.323155  118.0  179.00
# Distance from Residence to Work  500.0   29.978   15.068498    5.0   16.00
# Service time                     500.0   12.650    4.036345    3.0   10.00
# Age                              500.0   36.660    6.137731   27.0   33.00
# Hit target                       500.0   94.168    3.912338   81.0   92.00
# Disciplinary failure             500.0    0.064    0.244998    0.0    0.00
# ...

# %% [markdown]
# ## Merge train and test data for transformation

# %%
train_test = [train,test]

# %% [markdown]
# - Disciplinary failure (yes=1; no=0)
# - Education (high school (1), graduate (2), postgraduate (3), master and doctor (4))
# - Son (number of children)
# - Social drinker (yes=1; no=0)
# - Social smoker (yes=1; no=0)

# %%
for dataset in train_test:
    dataset['Day of the week'] = dataset['Day of the week'].replace({2:"Monday", 3:'Tuesday', 4:'Wednesday', 5:'Thursday', 6:'Friday'})
    dataset['Disciplinary failure']= dataset['Disciplinary failure'].replace({0:'No', 1:'Yes'})
    dataset['Education'] = dataset['Education'].replace({1:'High School', 2: 'Graduate', 3: 'Postgraduate', 4:'Master and Doctor'})
    dataset['Social drinker']= dataset['Social drinker'].replace({0:'No', 1:'Yes'})
    dataset['Social smoker']= dataset['Social smoker'].replace({0:'No', 1:'Yes'})

# %%
train.Education.value_counts()
# Out:
# High School     436
# Postgraduate     38
# Graduate         26
# Name: Education, dtype: int64

# %%
test.drop(test[test['Month of absence']==0].index, inplace = True)
test_copy2 = test.copy()

# %%
train.head()
# Out:
#    ID  Reason for absence  Month of absence Day of the week  Seasons  \
# 0   1                  26                 7         Tuesday        1
# 1   2                   0                 7         Tuesday        1
# 2   3                  23                 7       Wednesday        1
# 3   4                   7                 7        Thursday        1
# 4   5                  23                 7        Thursday        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#   Work load Average/day   Hit target Disciplinary failure    Education  Son  \
# ...

# %% [markdown]
# ### bar chart function

# %%
def dsc_chart(feature):
    absent = train[train['Absent']==1][feature].value_counts()
    notabsent = train[train['Absent']==0][feature].value_counts()
    df = pd.DataFrame([absent, notabsent])
    df.index=['Absent', 'Present']
    df.plot(kind='bar', stacked=True, figsize=(10,8))
    plt.ylabel(feature)
    plt.xlabel('Attendance Status')

# %%
dsc_chart('Education')
dsc_chart('Day of the week')
dsc_chart('Disciplinary failure')

# %% [markdown]
# # Plotting more charts

# %%
plt.rcParams['figure.figsize']=20,15
sns.heatmap(train.corr(), annot=True)

# %% [markdown]
# # Feature Engineering

# %%
def Care(train):
    if train.Pet >=1 and train.Son >=1:
        return "High"
    elif train.Pet<1 and train.Son >=1:
        return "Moderate"
    elif train.Pet >= 1 and train.Son <1:
        return 'Moderate'
    else:
        return 'No care'
train['CareDemand'] = train.apply(lambda train:Care(train), axis=1)

def Care(test):
    if test.Pet >=1 and test.Son >=1:
        return "High"
    elif test.Pet<1 and test.Son >=1:
        return "Moderate"
    elif test.Pet >= 1 and test.Son <1:
        return 'Moderate'
    else:
        return 'No care'
test['CareDemand'] = test.apply(lambda test:Care(test), axis=1)

# %%
test.head()
# Out:
#     ID  Reason for absence  Month of absence Day of the week  Seasons  \
# 0  501                  23                 9          Friday        1
# 1  502                  23                 9          Friday        1
# 2  503                  23                 9          Monday        1
# 3  504                  23                 9       Wednesday        1
# 4  505                  23                 9          Monday        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     179                               26             9   30
# 1                     248                               25            14   47
# 2                     179                               51            18   38
# 3                     225                               26             9   28
# 4                     179                               26             9   30
#
# ...

# %% [markdown]
# ## Density Plot

# %%
def kdplot(feature):
    facet = sns.FacetGrid(train, hue = 'Absent', aspect = 5)
    facet.map(sns.kdeplot, feature, shade=True)
    facet.set(xlim=(train[feature].min(), train[feature].max()))
    facet.add_legend()

# %%
kdplot('Transportation expense')
kdplot('Distance from Residence to Work')
kdplot('Age')

# %%
trans = pd.cut(train['Transportation expense'],bins=[0,155,190,225,320,400],labels=['Very Affordable','Affordable','Average','Expensive', 'Very Expensive'])
train.insert(5,'TransportFare',trans)

trans = pd.cut(test['Transportation expense'],bins=[0,155,190,225,320,400],labels=['Very Affordable','Affordable','Average','Expensive', 'Very Expensive'])
test.insert(5,'TransportFare',trans)

dist = pd.cut(train['Distance from Residence to Work'],bins=[0,24,60],labels=['Close distance','Far distance'])
train.insert(5,'Dist',dist)

dist = pd.cut(test['Distance from Residence to Work'],bins=[0,24,60],labels=['Close distance','Far distance'])
test.insert(5,'Dist',dist)

age = pd.cut(train['Age'],bins=[0,32,42,60],labels=['Less than 27','27-42','43 and above'])
train.insert(5,'Age_group',age)

age = pd.cut(test['Age'],bins=[0,32,42,60],labels=['Less than 27','27-42','43 and above'])
test.insert(5,'Age_group',age)

# %%
test.head()
# Out:
#     ID  Reason for absence  Month of absence Day of the week  Seasons  \
# 0  501                  23                 9          Friday        1
# 1  502                  23                 9          Friday        1
# 2  503                  23                 9          Monday        1
# 3  504                  23                 9       Wednesday        1
# 4  505                  23                 9          Monday        1
#
#       Age_group          Dist TransportFare  Transportation expense  \
# 0  Less than 27  Far distance    Affordable                     179
# 1  43 and above  Far distance     Expensive                     248
# 2         27-42  Far distance    Affordable                     179
# 3  Less than 27  Far distance       Average                     225
# 4  Less than 27  Far distance    Affordable                     179
#
#    Distance from Residence to Work  Service time  Age  Work load Average/day   \
# ...

# %%
train.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Age_group', 'Dist', 'TransportFare',
#        'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index', 'Absent',
#        'CareDemand'],
#       dtype='object')

# %%
drop = ['ID', 'Reason for absence', 'Transportation expense', 'Distance from Residence to Work', 'Age', 'Son', 'Pet','Seasons', 'Weight'
       , 'Height', 'Work load Average/day ']
train = train.drop(drop, axis=1)
test = test.drop(drop, axis=1)

# %%
train.dtypes
# Out:
# Month of absence           int64
# Day of the week           object
# Age_group               category
# Dist                    category
# TransportFare           category
# Service time               int64
# Hit target                 int64
# Disciplinary failure      object
# Education                 object
# Social drinker            object
# Social smoker             object
# Body mass index            int64
# Absent                     int64
# CareDemand                object
# dtype: object

# %%
train.head()
# Out:
#    Month of absence Day of the week     Age_group            Dist  \
# 0                 7         Tuesday         27-42    Far distance
# 1                 7         Tuesday  43 and above  Close distance
# 2                 7       Wednesday         27-42    Far distance
# 3                 7        Thursday         27-42  Close distance
# 4                 7        Thursday         27-42    Far distance
#
#      TransportFare  Service time  Hit target Disciplinary failure  \
# 0        Expensive            13          97                   No
# 1  Very Affordable            18          97                  Yes
# 2       Affordable            18          97                   No
# 3        Expensive            14          97                   No
# 4        Expensive            13          97                   No
#
#      Education Social drinker Social smoker  Body mass index  Absent  \
# 0  High School            Yes            No               30       1
# ...

# %%
train.Dist.value_counts()
# Out:
# Far distance      337
# Close distance    163
# Name: Dist, dtype: int64

# %% [markdown]
# # Modelling

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

binary = ['Dist', 'Disciplinary failure', 'Social drinker', 'Social smoker']
multi = ['Month of absence', 'Day of the week', 'Age_group', 'TransportFare', 'Education', 'CareDemand']

le = LabelEncoder()
for i in binary:
    train[i] = le.fit_transform(train[i])
for i in binary:
    test[i] = le.fit_transform(test[i])
    
train = pd.get_dummies(data= train, columns = multi)
test = pd.get_dummies(data = test, columns = multi)

# %%
train.head()
# Out:
#    Dist  Service time  Hit target  Disciplinary failure  Social drinker  \
# 0     1            13          97                     0               1
# 1     0            18          97                     1               1
# 2     1            18          97                     0               1
# 3     0            14          97                     0               1
# 4     1            13          97                     0               1
#
#    Social smoker  Body mass index  Absent  Month of absence_1  \
# 0              0               30       1                   0
# 1              0               31       0                   0
# 2              0               31       1                   0
# 3              1               24       1                   0
# 4              0               30       1                   0
#
#    Month of absence_2  Month of absence_3  Month of absence_4  \
# 0                   0                   0                   0
# ...

# %%
train.shape, test.shape
# Out:
# ((500, 39), (237, 38))

# %%
features = train.drop('Absent', axis=True)
target = train['Absent']

# %% [markdown]
# ## Scaling Features and test data

# %%
scaler = StandardScaler()
scaler.fit(features)
scaler.fit(test)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Split Train and Test data

# %% [markdown]
#  This test data here is different from the test data to be submitted on Kaggle

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.30, random_state = 30)

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
print('Train data score: ', clf.score(X_train,y_train))
print('Validation data score: ', clf.score(X_test,y_test))
# Out:
# Train data score:  0.9685714285714285
# Validation data score:  0.7533333333333333

# %% [markdown]
# ## Logistics Regression

# %%
from sklearn.linear_model import LogisticRegression
clf2 = LogisticRegression()
clf2.fit(X_train,y_train)
print('Train data score: ', clf2.score(X_train,y_train))
print('Validation data score: ', clf2.score(X_test,y_test))
# Out:
# Train data score:  0.8371428571428572
# Validation data score:  0.9133333333333333

# %% [markdown]
# # Prediction

# %%
prediction = clf2.predict(test)
prediction.shape, test.shape
# Out:
# ((237,), (237, 38))

# %%
test.head()
# Out:
#    Dist  Service time  Hit target  Disciplinary failure  Social drinker  \
# 0     1             9          87                     0               0
# 1     1            14          87                     0               0
# 2     1            18          87                     0               1
# 3     1             9          87                     0               0
# 4     1             9          87                     0               0
#
#    Social smoker  Body mass index  Month of absence_1  Month of absence_2  \
# 0              0               19                   0                   0
# 1              0               32                   0                   0
# 2              0               31                   0                   0
# 3              0               24                   0                   0
# 4              0               19                   0                   0
#
#    Month of absence_3  Month of absence_4  Month of absence_5  \
# ...

# %%
submission = pd.DataFrame({
    "ID": test_copy2['ID'],
    "Absent": prediction
})

# %%
submission.head()
# Out:
#     ID  Absent
# 0  501       0
# 1  502       1
# 2  503       0
# 3  504       1
# 4  505       1

# %%
submission['Absent'] = submission['Absent'].replace({1:"Yes", 0:"No"})

# %%
submission.head()
# Out:
#     ID Absent
# 0  501     No
# 1  502    Yes
# 2  503     No
# 3  504    Yes
# 4  505    Yes

# %%
submission.to_csv('submission.csv', index=False)
